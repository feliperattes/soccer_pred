# %%
import pandas as pd

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: 4C94-1FB3
#
#  Directorio de C:\Users\sanch\code\feliperattes\soccer_pred\notebooks
#
# 26/11/2020  01:56 p. m.    <DIR>          .
# 26/11/2020  01:56 p. m.    <DIR>          ..
# 26/11/2020  01:56 p. m.    <DIR>          .ipynb_checkpoints
# 24/11/2020  04:58 p. m.            77,291 Brazilean DataSet.ipynb
# 25/11/2020  11:08 p. m.            75,668 Getting Data.ipynb
# 25/11/2020  08:40 p. m.           446,830 Over Goals.ipynb
# 26/11/2020  01:10 p. m.           347,069 Scraping (3).ipynb
# 25/11/2020  04:15 p. m.           277,781 Scraping.ipynb
# 25/11/2020  04:23 p. m.           219,963 Scraping_colab.ipynb
# 26/11/2020  01:21 p. m.           346,522 Scraping_test (1).ipynb
# 26/11/2020  01:55 p. m.         1,080,560 soccer_clean_matchreport.csv
# 26/11/2020  01:55 p. m.         1,099,572 soccer_stupid_shit.csv
# 25/11/2020  08:23 p. m.           471,385 soccer2.csv
# ...

# %%
matches_df = pd.read_csv("soccer_clean_matchreport.csv")

# %%
matches_df_2 = pd.read_csv("soccer_stupid_shit.csv")

# %%
matches_df.match_report_link
# Out:
# 0       https://fbref.com/en/matches/d4af3198/Flamengo...
# 1       https://fbref.com/en/matches/97072c2b/Palmeira...
# 2       https://fbref.com/en/matches/ef847dd8/Avai-Vit...
# 3       https://fbref.com/en/matches/76a50f6c/Coritiba...
# 4       https://fbref.com/en/matches/cc0675a6/Chapecoe...
#                               ...
# 1353    https://fbref.com/en/matches/b6ee4cd1/Atletico...
# 1354    https://fbref.com/en/matches/5d5bae5e/Flamengo...
# 1355    https://fbref.com/en/matches/dd0e7e1e/Sao-Paul...
# 1356    https://fbref.com/en/matches/bb50b702/Internac...
# 1357    https://fbref.com/en/matches/9e4e8ba1/Ceara-Sa...
# Name: match_report_link, Length: 1358, dtype: object

# %%
matches_df_2.match_report_link
# Out:
# 0       [('https://fbref.com/en/matches/d4af3198/Flame...
# 1       [('https://fbref.com/en/matches/97072c2b/Palme...
# 2       [('https://fbref.com/en/matches/ef847dd8/Avai-...
# 3       [('https://fbref.com/en/matches/76a50f6c/Corit...
# 4       [('https://fbref.com/en/matches/cc0675a6/Chape...
#                               ...
# 1353    [('https://fbref.com/en/matches/b6ee4cd1/Atlet...
# 1354    [('https://fbref.com/en/matches/5d5bae5e/Flame...
# 1355    [('https://fbref.com/en/matches/dd0e7e1e/Sao-P...
# 1356    [('https://fbref.com/en/matches/bb50b702/Inter...
# 1357    [('https://fbref.com/en/matches/9e4e8ba1/Ceara...
# Name: match_report_link, Length: 1358, dtype: object

# %%
matches_df
# Out:
#                                       match_report_link  \
# 0     https://fbref.com/en/matches/d4af3198/Flamengo...
# 1     https://fbref.com/en/matches/97072c2b/Palmeira...
# 2     https://fbref.com/en/matches/ef847dd8/Avai-Vit...
# 3     https://fbref.com/en/matches/76a50f6c/Coritiba...
# 4     https://fbref.com/en/matches/cc0675a6/Chapecoe...
# ...                                                 ...
# 1353  https://fbref.com/en/matches/b6ee4cd1/Atletico...
# 1354  https://fbref.com/en/matches/5d5bae5e/Flamengo...
# 1355  https://fbref.com/en/matches/dd0e7e1e/Sao-Paul...
# 1356  https://fbref.com/en/matches/bb50b702/Internac...
# 1357  https://fbref.com/en/matches/9e4e8ba1/Ceara-Sa...
#
#                     HomeFouls              HomeCorners  \
# 0      [('7', 'Fouls', '10')]  [('4', 'Corners', '6')]
# 1     [('19', 'Fouls', '16')]  [('3', 'Corners', '2')]
# 2      [('6', 'Fouls', '15')]  [('7', 'Corners', '4')]
# 3     [('17', 'Fouls', '13')]  [('6', 'Corners', '6')]
# ...

# %%
matches_df_2
# Out:
#                                       match_report_link  \
# 0     [('https://fbref.com/en/matches/d4af3198/Flame...
# 1     [('https://fbref.com/en/matches/97072c2b/Palme...
# 2     [('https://fbref.com/en/matches/ef847dd8/Avai-...
# 3     [('https://fbref.com/en/matches/76a50f6c/Corit...
# 4     [('https://fbref.com/en/matches/cc0675a6/Chape...
# ...                                                 ...
# 1353  [('https://fbref.com/en/matches/b6ee4cd1/Atlet...
# 1354  [('https://fbref.com/en/matches/5d5bae5e/Flame...
# 1355  [('https://fbref.com/en/matches/dd0e7e1e/Sao-P...
# 1356  [('https://fbref.com/en/matches/bb50b702/Inter...
# 1357  [('https://fbref.com/en/matches/9e4e8ba1/Ceara...
#
#                     HomeFouls              HomeCorners  \
# 0      [('7', 'Fouls', '10')]  [('4', 'Corners', '6')]
# 1     [('19', 'Fouls', '16')]  [('3', 'Corners', '2')]
# 2      [('6', 'Fouls', '15')]  [('7', 'Corners', '4')]
# 3     [('17', 'Fouls', '13')]  [('6', 'Corners', '6')]
# ...
