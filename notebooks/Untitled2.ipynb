# %%
import pandas as pd

# %%
matches_df = pd.read_csv("featured_data.csv")

# %%
matches_df = matches_df.drop(["Unnamed: 0", "index", "Index"], axis=1)
matches_df
# Out:
#                     HT Score                AT  \
# 0             Flamengo   1–1  Atlético Mineiro
# 1          Corinthians   1–1       Chapecoense
# 2           Fluminense   3–2            Santos
# 3            Palmeiras   4–0     Vasco da Gama
# 4                Bahia   6–2    Atl Paranaense
# ...                ...   ...               ...
# 1283       Corinthians   0–0            Grêmio
# 1284      Sport Recife   0–1    Atl Goianiense
# 1285             Ceará   1–1         São Paulo
# 1286  Atlético Mineiro   2–1     Botafogo (RJ)
# 1287          Coritiba   0–1       Corinthians
#
#                              referee  HomeGoals  AwayGoals  \
# 0             Jailson Macêdo Freitas          1          1
# 1           Elmo Alves Resende Cunha          1          1
# 2                       Wagner Reway          3          2
# 3             Rodolpho Toski Marques          4          0
# 4          Flavio Rodrigues De Souza          6          2
# ...
