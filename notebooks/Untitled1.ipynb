# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El n£mero de serie del volumen es: 4C94-1FB3
#
#  Directorio de C:\Users\sanch\code\feliperattes\soccer_pred\notebooks
#
# 27/11/2020  04:52 p. m.           229,343 # Corners Model.ipynb
# 30/11/2020  09:49 a. m.    <DIR>          .
# 30/11/2020  09:49 a. m.    <DIR>          ..
# 30/11/2020  09:49 a. m.    <DIR>          .ipynb_checkpoints
# 24/11/2020  04:58 p. m.            77,291 Brazilean DataSet.ipynb
# 27/11/2020  10:09 a. m.           447,694 Over Goals.ipynb
# 26/11/2020  02:42 p. m.           270,775 partial_df.csv
# 26/11/2020  02:05 p. m.           349,052 Scraping (3).ipynb
# 25/11/2020  04:15 p. m.           277,781 Scraping.ipynb
# 25/11/2020  04:23 p. m.           219,963 Scraping_colab.ipynb
# 26/11/2020  01:21 p. m.           346,522 Scraping_test (1).ipynb
# 27/11/2020  06:11 p. m.           101,837 Soccer Final.ipynb
# 26/11/2020  05:20 p. m.            94,975 Soccer Pred with poss.ipynb
# 26/11/2020  01:55 p. m.         1,080,560 soccer_clean_matchreport.csv
# 26/11/2020  05:10 p. m.           361,741 soccer_final.csv
# 26/11/2020  01:55 p. m.         1,099,572 soccer_stupid_shit.csv
# 25/11/2020  08:23 p. m.           471,385 soccer2.csv
# 26/11/2020  02:05 p. m.           270,775 SoccerPoss.csv
# 26/11/2020  02:00 p. m.            54,473 Untitled.ipynb
# 30/11/2020  09:49 a. m.                72 Untitled1.ipynb
#               17 archivos      5,753,811 bytes
#                3 dirs  1,787,312,144,384 bytes libres

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.preprocessing import MinMaxScaler

# %%
matches_df = pd.read_csv("../Data/soccer.csv")

# %%
matches_df
# Out:
#                   HT Score                AT  HomeGoals  AwayGoals  Home_Poss  \
# 0           Flamengo   1–1  Atlético Mineiro          1          1       0.42
# 1        Corinthians   1–1       Chapecoense          1          1       0.67
# 2         Fluminense   3–2            Santos          3          2       0.38
# 3          Palmeiras   4–0     Vasco da Gama          4          0       0.51
# 4              Bahia   6–2    Atl Paranaense          6          2       0.40
# ...              ...   ...               ...        ...        ...        ...
# 1341       Fortaleza   1–1             Goiás          1          1       0.70
# 1342       Palmeiras   3–0    Atl Paranaense          3          0       0.58
# 1343          Santos   4–2      Sport Recife          4          2       0.59
# 1344           Bahia   1–3         São Paulo          1          3       0.37
# 1345  Atl Goianiense   0–0     Internacional          0          0       0.42
#
#       Away_Poss  Home_PA  Away_PA  Home_ShoT  ...  AwayCrosses  AwayTouches  \
# 0          0.58       77       82         27  ...           15          701
# 1          0.33       84       74         40  ...           22          496
# 2          0.62       86       89         56  ...           21          684
# 3          0.49       86       84         56  ...           16          562
# 4          0.60       81       86         37  ...           10          669
# ...         ...      ...      ...        ...  ...          ...          ...
# 1341       0.30       88       68         53  ...            6          413
# 1342       0.42       88       77         36  ...            5          504
# 1343       0.41       86       77         45  ...           12          442
# 1344       0.63       81       90         40  ...           41          802
# 1345       0.58       73       84          0  ...           26          584
#
#       AwayTackles  AwayInterceptions  AwayAerials  AwayClearances  \
# 0              15                 18           10              27
# 1              17                 22           17              16
# 2              13                  4           12              22
# 3              18                 17            6              11
# 4              15                 12           11              30
# ...           ...                ...          ...             ...
# 1341           11                 13           10              21
# 1342           10                 11            9              16
# 1343           14                 19           10               8
# 1344            9                 20           17              15
# 1345           14                 16           19              23
#
#       AwayOffsides  AwayGoalKicks  AwayThrowIns  AwayLongBalls
# 0                1             11            26             54
# 1                3              4            24             43
# 2                2              5            22             24
# 3                2              5            22             41
# 4                1             10            21             35
# ...            ...            ...           ...            ...
# 1341             0             10            13             65
# 1342             2             12            19             50
# 1343             0              8            14             49
# 1344             1              5            14             31
# 1345             4              7            16             54
#
# [1346 rows x 37 columns]

# %%
matches_df.isnull().sum()
# Out:
# HT                    0
# Score                 0
# AT                    0
# HomeGoals             0
# AwayGoals             0
# Home_Poss             0
# Away_Poss             0
# Home_PA               0
# Away_PA               0
# Home_ShoT             0
# Away_ShoT             0
# Home_Saves           44
# Away_Saves           10
# HomeFouls             0
# HomeCorners           0
# HomeCrosses           0
# HomeTouches           0
# HomeTackles           0
# HomeInterceptions     0
# HomeAerials           0
# HomeClearances        0
# HomeOffsides          0
# HomeGoalKicks         0
# HomeThrowIns          0
# HomeLongBalls         0
# AwayFouls             0
# AwayCorners           0
# AwayCrosses           0
# AwayTouches           0
# AwayTackles           0
# AwayInterceptions     0
# AwayAerials           0
# AwayClearances        0
# AwayOffsides          0
# AwayGoalKicks         0
# AwayThrowIns          0
# AwayLongBalls         0
# dtype: int64

# %%
matches_df = matches_df.dropna()
matches_df.shape
# Out:
# (1292, 37)

# %%
matches_df['goal_difference'] = matches_df['HomeGoals'] - matches_df['AwayGoals']
matches_df["Sum_Goals"] = matches_df["HomeGoals"] + matches_df["AwayGoals"]
matches_df
# Out:
# C:\Users\sanch\anaconda3\envs\lewagon_conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\sanch\anaconda3\envs\lewagon_conda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     HT Score                AT  HomeGoals  AwayGoals  \
# 0             Flamengo   1–1  Atlético Mineiro          1          1
# 1          Corinthians   1–1       Chapecoense          1          1
# 2           Fluminense   3–2            Santos          3          2
# 3            Palmeiras   4–0     Vasco da Gama          4          0
# 4                Bahia   6–2    Atl Paranaense          6          2
# ...                ...   ...               ...        ...        ...
# 1340  Atlético Mineiro   2–1     Botafogo (RJ)          2          1
# 1341         Fortaleza   1–1             Goiás          1          1
# 1342         Palmeiras   3–0    Atl Paranaense          3          0
# 1343            Santos   4–2      Sport Recife          4          2
# 1344             Bahia   1–3         São Paulo          1          3
#
#       Home_Poss  Away_Poss  Home_PA  Away_PA  Home_ShoT  ...  AwayTackles  \
# 0          0.42       0.58       77       82         27  ...           15
# 1          0.67       0.33       84       74         40  ...           17
# 2          0.38       0.62       86       89         56  ...           13
# 3          0.51       0.49       86       84         56  ...           18
# 4          0.40       0.60       81       86         37  ...           15
# ...         ...        ...      ...      ...        ...  ...          ...
# 1340       0.54       0.46       87       82         55  ...           14
# 1341       0.70       0.30       88       68         53  ...           11
# 1342       0.58       0.42       88       77         36  ...           10
# 1343       0.59       0.41       86       77         45  ...           14
# 1344       0.37       0.63       81       90         40  ...            9
#
#       AwayInterceptions  AwayAerials  AwayClearances  AwayOffsides  \
# 0                    18           10              27             1
# 1                    22           17              16             3
# 2                     4           12              22             2
# 3                    17            6              11             2
# 4                    12           11              30             1
# ...                 ...          ...             ...           ...
# 1340                  9            9              12             4
# 1341                 13           10              21             0
# 1342                 11            9              16             2
# 1343                 19           10               8             0
# 1344                 20           17              15             1
#
#       AwayGoalKicks  AwayThrowIns  AwayLongBalls  goal_difference  Sum_Goals
# 0                11            26             54                0          2
# 1                 4            24             43                0          2
# 2                 5            22             24                1          5
# 3                 5            22             41                4          4
# 4                10            21             35                4          8
# ...             ...           ...            ...              ...        ...
# 1340              4            18             67                1          3
# 1341             10            13             65                0          2
# 1342             12            19             50                3          3
# 1343              8            14             49                2          6
# 1344              5            14             31               -2          4
#
# [1292 rows x 39 columns]
